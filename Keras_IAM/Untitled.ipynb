# %%
import tensorflow as tf
import keras
import numpy as np

# Load your trained model
model = keras.models.load_model('models/model1.keras')

# You need to provide this manually!
# Replace X with the correct value (you printed "Maximum length" during training)
max_len = 22  # e.g. max_len = 22

# Use your existing num_to_char (already defined in your notebook!)
# from your previous cell: num_to_char = StringLookup(...).invert()

# Reuse your distortion_free_resize() exactly as defined:
def distortion_free_resize(image, img_size):
    w, h = img_size
    image = tf.image.resize(image, size=(h, w), preserve_aspect_ratio=True)

    pad_height = h - tf.shape(image)[0]
    pad_width = w - tf.shape(image)[1]

    if pad_height % 2 != 0:
        height = pad_height // 2
        pad_height_top = height + 1
        pad_height_bottom = height
    else:
        pad_height_top = pad_height_bottom = pad_height // 2

    if pad_width % 2 != 0:
        width = pad_width // 2
        pad_width_left = width + 1
        pad_width_right = width
    else:
        pad_width_left = pad_width_right = pad_width // 2

    image = tf.pad(
        image,
        paddings=[
            [pad_height_top, pad_height_bottom],
            [pad_width_left, pad_width_right],
            [0, 0],
        ],
    )

    image = tf.transpose(image, (1, 0, 2))
    image = tf.image.flip_left_right(image)

    return image

# Reuse your preprocess_image() exactly as defined:
def preprocess_image(image_path, img_size=(128, 32)):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, 1)  # Grayscale
    image = distortion_free_resize(image, img_size)
    image = tf.cast(image, tf.float32) / 255.0
    return image

# Final utility function:
def predict_text_from_image(image_path, model, max_len, num_to_char):
    # Preprocess
    img = preprocess_image(image_path)
    img = tf.expand_dims(img, axis=0)  # Add batch dimension

    # Predict
    preds = model.predict(img)

    # Decode (reuse your decode_batch_predictions logic)
    input_len = np.ones(preds.shape[0]) * preds.shape[1]
    results = keras.ops.nn.ctc_decode(preds, sequence_lengths=input_len)[0][0][:, :max_len]

    # Convert to string
    output_text = []
    for res in results:
        res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
        res = (
            tf.strings.reduce_join(num_to_char(res))
            .numpy()
            .decode("utf-8")
            .replace("[UNK]", "")
        )
        output_text.append(res)

    return output_text[0]  # Single image → single result

# Example usage:
# text = predict_text_from_image('path/to/your_image.png', model, max_len, num_to_char)
# print("Predicted text:", text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/envs/ai_project/lib/python3.12/site-packages/keras/src/saving/serialization_lib.py:718, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     717 try:
# --> 718     instance = cls.from_config(inner_config)
#     719 except TypeError as e:
#
# File /opt/anaconda3/envs/ai_project/lib/python3.12/site-packages/keras/src/models/model.py:526, in Model.from_config(cls, config, custom_objects)
#     524     from keras.src.models.functional import functional_from_config
# --> 526     return functional_from_config(
#     527         cls, config, custom_objects=custom_objects
#     528     )
#     530 # Either the model has a custom __init__, or the config
#     531 # does not contain all the information necessary to
#     532 # revive a Functional model. This happens when the user creates
# ...

# %%
text = predict_text_from_image('samples/test1.png', model, max_len, num_to_char)
print("Predicted text:", text)
